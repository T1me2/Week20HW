# %%
#dependencies 
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import pandas as pd
from pathlib import Path
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %%
df = pd.read_csv('Starter_Code/myopia.csv')
df
# Out:
#      AGE  SPHEQ         AL    ACD     LT    VCD  SPORTHR  READHR  COMPHR  \
# 0      6 -0.052  21.889999  3.690  3.498  14.70       45       8       0
# 1      6  0.608  22.379999  3.702  3.392  15.29        4       0       1
# 2      6  1.179  22.490000  3.462  3.514  15.52       14       0       2
# 3      6  0.525  22.200001  3.862  3.612  14.73       18      11       0
# 4      5  0.697  23.290001  3.676  3.454  16.16       14       0       0
# ..   ...    ...        ...    ...    ...    ...      ...     ...     ...
# 613    6  0.678  22.400000  3.663  3.803  14.93        2       0       7
# 614    6  0.665  22.500000  3.570  3.378  15.56        6       0       1
# 615    6  1.834  22.940001  3.624  3.424  15.89        8       0       0
# 616    6  0.665  21.920000  3.688  3.598  14.64       12       2       1
# 617    6  0.802  22.260000  3.530  3.484  15.25       25       0       2
#
#      STUDYHR  TVHR  DIOPTERHR  MOMMY  DADMY  MYOPIC
# ...

# %%
#drop myopic column
df2 = df.drop(['MYOPIC'], axis=1)

# %%
#standarize data
df_scaled = StandardScaler().fit_transform(df2)

# %%
# Initialize PCA model
pca = PCA(n_components=2)
# Get two principal components for the iris data.
data_pca = pca.fit_transform(df_scaled)
data_pca
# Out:
# array([[ 0.53550271,  1.14500427],
#        [-0.62470559, -1.57578643],
#        [-0.93347937, -0.71707622],
#        ...,
#        [-0.89008202, -2.3080052 ],
#        [-1.12399979,  0.45188978],
#        [-0.69153391, -0.73704619]])

# %% [markdown]
# ### The number of componets are reduced to 2

# %%
#convert PCA data to df
df_pca = pd.DataFrame(
    data=data_pca, columns=['PC1', 'PC2']
)
df_pca
# Out:
#           PC1       PC2
# 0    0.535503  1.145004
# 1   -0.624706 -1.575786
# 2   -0.933479 -0.717076
# 3    0.106354  1.192475
# 4   -0.388503 -2.839655
# ..        ...       ...
# 613 -0.237547  1.146547
# 614 -0.649011 -1.796952
# 615 -0.890082 -2.308005
# 616 -1.124000  0.451890
# 617 -0.691534 -0.737046
#
# [618 rows x 2 columns]

# %%
#use the PCA output to run a t-SNE model
#initialize t-SNE model
tsne= TSNE(learning_rate=34)

#reduce dimentions
tsne_features = tsne.fit_transform(df_pca)
# Out:
# C:\Anaconda\envs\mlenv\lib\site-packages\sklearn\manifold\_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,

# %%
#prepare data to plot
df_pca['x'] = tsne_features[:,0]
df_pca['y'] = tsne_features[:,1]

# %%
#plot results
plt.scatter(df_pca['x'], df_pca['y'])
plt.show()

# %% [markdown]
# ### PCA does not show distict clusters

# %%
#set up k-means analysis 
inertia = []
k = list(range(1, 10))

# Calculate the inertia for the range of k values
for i in k:
    km = KMeans(n_clusters=i, random_state=0)
    km.fit(df_scaled)
    inertia.append(km.inertia_)
    
# Create the Elbow Curve using hvPlot
elbow_data = {"k": k, "inertia": inertia}
df_elbow = pd.DataFrame(elbow_data)
df_elbow.head()
# Out:
# C:\Anaconda\envs\mlenv\lib\site-packages\sklearn\cluster\_kmeans.py:1037: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   "KMeans is known to have a memory leak on Windows "
#    k      inertia
# 0  1  8652.000000
# 1  2  7497.115123
# 2  3  6732.095466
# 3  4  6362.286058
# 4  5  6083.180361

# %%
# Plot the elbow curve to find the best candidate(s) for k
plt.plot(df_elbow['k'], df_elbow['inertia'])
plt.xticks(range(1,11))
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.title('MYOPIC')
plt.show()

# %% [markdown]
# ### The elbow curve is difficult to determine. 6 might be the best option because it is lower than the other possible option of 3.

# %% [markdown]
# ### Recommendation: my recommendation would be to use the K-Means analysis for this data. There are more than 2 distict clusters shown by the overlap in the TSNE model. Patients have a better chance of being clustered using K-Means.
